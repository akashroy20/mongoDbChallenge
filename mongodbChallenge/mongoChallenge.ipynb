# %%
import pymongo
db_name = input("Enter name of your database: ")
collection_name = input("Enter name of your collection: ")
client = pymongo.MongoClient(input("Enter your connection string: "))
db = client.test
db2 = client[db_name]
coll1 = db2[collection_name]
# Out:
# Enter name of your database: carbon_nanotubes
# Enter name of your collection: carbon_nanotubes_db_1
# Enter your connection string: mongodb+srv://Akmongo:amongo@cluster0.sdfyq.mongodb.net/myFirstDatabase?retryWrites=true&w=majority

# %%
import mc

# %%
mc.data_transfer(coll1)

# %%
import pandas as pd
l = []
for i in coll1.find():
    l.append(i)
pd.DataFrame(l)
# Out:
#                             _id  Chiral indice n  Chiral indice m  \
# 0      6215b8a9e5457239043adbed              2.0              1.0
# 1      6215b8a9e5457239043adbee              2.0              1.0
# 2      6215b8a9e5457239043adbef              2.0              1.0
# 3      6215b8a9e5457239043adbf0              2.0              1.0
# 4      6215b8a9e5457239043adbf1              2.0              1.0
# ...                         ...              ...              ...
# 10715  6215b8a9e5457239043b05c8             12.0              6.0
# 10716  6215b8a9e5457239043b05c9             12.0              6.0
# 10717  6215b8a9e5457239043b05ca             12.0              6.0
# 10718  6215b8a9e5457239043b05cb             12.0              6.0
# 10719  6215b8a9e5457239043b05cc             12.0              6.0
#
#        Initial atomic coordinate u  Initial atomic coordinate v  \
# 0                         0.717298                     0.642129
# ...

# %%
ag = coll1.aggregate(
    [{
        '$group':{'_id':'$Chiral indice m','No of records':{'$sum':1}}
    }])
for i in ag:
    print(i)
# Out:
# {'_id': 1.0, 'No of records': 1786}
# {'_id': 2.0, 'No of records': 2419}
# {'_id': 3.0, 'No of records': 1539}
# {'_id': 5.0, 'No of records': 1456}
# {'_id': 6.0, 'No of records': 1588}
# {'_id': 4.0, 'No of records': 1932}

# %%
ag = coll1.aggregate(
    [{
        '$group':{'_id':'$Chiral indice n','No of records':{'$sum':1}}
    }])
for i in ag:
    print(i)
# Out:
# {'_id': 12.0, 'No of records': 972}
# {'_id': 8.0, 'No of records': 1772}
# {'_id': 9.0, 'No of records': 1689}
# {'_id': 11.0, 'No of records': 588}
# {'_id': 6.0, 'No of records': 875}
# {'_id': 3.0, 'No of records': 128}
# {'_id': 5.0, 'No of records': 719}
# {'_id': 2.0, 'No of records': 27}
# {'_id': 4.0, 'No of records': 288}
# {'_id': 7.0, 'No of records': 2126}
# {'_id': 10.0, 'No of records': 1536}

# %%
l = []
for i in coll1.find({'Chiral indice n':2.0 , 'Chiral indice m': 1.0}):
    l.append(i)
pd.DataFrame(l)
# Out:
#                          _id  Chiral indice n  Chiral indice m  \
# 0   6215b8a9e5457239043adbed              2.0              1.0
# 1   6215b8a9e5457239043adbee              2.0              1.0
# 2   6215b8a9e5457239043adbef              2.0              1.0
# 3   6215b8a9e5457239043adbf0              2.0              1.0
# 4   6215b8a9e5457239043adbf1              2.0              1.0
# 5   6215b8a9e5457239043adbf2              2.0              1.0
# 6   6215b8a9e5457239043adbf3              2.0              1.0
# 7   6215b8a9e5457239043adbf4              2.0              1.0
# 8   6215b8a9e5457239043adbf5              2.0              1.0
# 9   6215b8a9e5457239043adbf6              2.0              1.0
# 10  6215b8a9e5457239043adbf7              2.0              1.0
# 11  6215b8a9e5457239043adbf8              2.0              1.0
# 12  6215b8a9e5457239043adbf9              2.0              1.0
# 13  6215b8a9e5457239043adbfa              2.0              1.0
# ...

# %%
coll2 = db2['Chiral_indice_n_1_Chiral_indice_m_2']
coll2.insert_many(l)

# %%
ag1 = coll2.aggregate(
    [{
        '$group':{'_id':'$Chiral indice m','No of records having chiral indice n equals 1 and Chiral indice m equals 2':{'$sum':1}}
    }])
for i in ag1:
    print(i)
# Out:
# {'_id': 1.0, 'No of records having chiral indice n equals 1 and Chiral indice m equals 2': 27}

# %%
la = []
ag2 = coll2.aggregate(
    [{
        '$group':{'_id':'$Chiral indice m','Mean of initial atomic coordinate u':{'$avg':'$Initial atomic coordinate u'},"mean of calculated atomic coordinates u'":{'$avg':"$Calculated atomic coordinates u'"}}
    }])
for i in ag2:
    la.append(i)
a = pd.DataFrame(la)
a['difference'] = a['Mean of initial atomic coordinate u']-a["mean of calculated atomic coordinates u'"]
a
# Out:
#    _id  Mean of initial atomic coordinate u  \
# 0  1.0                              0.49337
#
#    mean of calculated atomic coordinates u'  difference
# 0                                  0.491813    0.001557

# %%
la = []
ag2 = coll2.aggregate(
    [{
        '$group':{'_id':'$Chiral indice m','Mean of initial atomic coordinate v':{'$avg':'$Initial atomic coordinate v'},"mean of calculated atomic coordinates v'":{'$avg':"$Calculated atomic coordinates v'"}}
    }])
for i in ag2:
    la.append(i)
a = pd.DataFrame(la)
a['difference'] = a['Mean of initial atomic coordinate v']-a["mean of calculated atomic coordinates v'"]
a
# Out:
#    _id  Mean of initial atomic coordinate v  \
# 0  1.0                             0.492544
#
#    mean of calculated atomic coordinates v'  difference
# 0                                  0.491473    0.001071

# %%
la = []
ag2 = coll2.aggregate(
    [{
        '$group':{'_id':'$Chiral indice m','Mean of initial atomic coordinate w':{'$avg':'$Initial atomic coordinate w'},"mean of calculated atomic coordinates w'":{'$avg':"$Calculated atomic coordinates w'"}}
    }])
for i in ag2:
    la.append(i)
a = pd.DataFrame(la)
a['difference'] = a['Mean of initial atomic coordinate w']-a["mean of calculated atomic coordinates w'"]
a
# Out:
#    _id  Mean of initial atomic coordinate w  \
# 0  1.0                              0.51086
#
#    mean of calculated atomic coordinates w'    difference
# 0                                  0.510861 -7.037037e-07

# %%
la = []
ag2 = coll2.aggregate(
    [{
        '$group':{'_id':'$Chiral indice m','Highest initial atomic coordinate u':{'$max':'$Initial atomic coordinate u'},"Highest calculated atomic coordinates u'":{'$max':"$Calculated atomic coordinates u'"}}
    }])
for i in ag2:
    la.append(i)
a = pd.DataFrame(la)
a['difference'] = a['Highest initial atomic coordinate u']-a["Highest calculated atomic coordinates u'"]
a
# Out:
#    _id  Highest initial atomic coordinate u  \
# 0  1.0                             0.717298
#
#    Highest calculated atomic coordinates u'  difference
# 0                                  0.770521   -0.053223

# %%
la = []
ag2 = coll2.aggregate(
    [{
        '$group':{'_id':'$Chiral indice m','Highest initial atomic coordinate v':{'$max':'$Initial atomic coordinate v'},"Highest calculated atomic coordinates v'":{'$max':"$Calculated atomic coordinates v'"}}
    }])
for i in ag2:
    la.append(i)
a = pd.DataFrame(la)
a['difference'] = a['Highest initial atomic coordinate v']-a["Highest calculated atomic coordinates v'"]
a
# Out:
#    _id  Highest initial atomic coordinate v  \
# 0  1.0                             0.720633
#
#    Highest calculated atomic coordinates v'  difference
# 0                                  0.766301   -0.045668

# %%
la = []
ag2 = coll2.aggregate(
    [{
        '$group':{'_id':'$Chiral indice m','Highest initial atomic coordinate w':{'$max':'$Initial atomic coordinate w'},"Highest calculated atomic coordinates w'":{'$max':"$Calculated atomic coordinates w'"}}
    }])
for i in ag2:
    la.append(i)
a = pd.DataFrame(la)
a['difference'] = a['Highest initial atomic coordinate w']-a["Highest calculated atomic coordinates w'"]
a
# Out:
#    _id  Highest initial atomic coordinate w  \
# 0  1.0                             0.969414
#
#    Highest calculated atomic coordinates w'  difference
# 0                                  0.969157    0.000257

# %%
coll2.update_many({'Initial atomic coordinate u':{'$lt':0.49337}},{'$set':{'Initial atomic coordinate u':'less than mean'},'$currentDate':{'lastModified':True}})

# %%
l = []
for i in coll2.find():
    l.append(i)
pd.DataFrame(l)
# Out:
#                          _id  Chiral indice n  Chiral indice m  \
# 0   6215b8a9e5457239043adbed              2.0              1.0
# 1   6215b8a9e5457239043adbee              2.0              1.0
# 2   6215b8a9e5457239043adbef              2.0              1.0
# 3   6215b8a9e5457239043adbf0              2.0              1.0
# 4   6215b8a9e5457239043adbf1              2.0              1.0
# 5   6215b8a9e5457239043adbf2              2.0              1.0
# 6   6215b8a9e5457239043adbf3              2.0              1.0
# 7   6215b8a9e5457239043adbf4              2.0              1.0
# 8   6215b8a9e5457239043adbf5              2.0              1.0
# 9   6215b8a9e5457239043adbf6              2.0              1.0
# 10  6215b8a9e5457239043adbf7              2.0              1.0
# 11  6215b8a9e5457239043adbf8              2.0              1.0
# 12  6215b8a9e5457239043adbf9              2.0              1.0
# 13  6215b8a9e5457239043adbfa              2.0              1.0
# ...

# %%
coll2.drop()
